# %%
import os
import yaml
import pymongo
import uuid

#根据日期和时间生成随机Id
def autoId():
    return uuid.uuid1(20201025) #自定义数字，防止机器抓硬件信息

class fuCamp:
    errors=''
    campObj=actionObj=indexObj={}
    
    def __loadYaml(self,fileLink):
        f=open(fileLink,'r',encoding='utf-8')
        fdata=f.read()
        fObj=yaml.load(fdata,Loader=yaml.FullLoader)
        return fObj

    def __init__(self,campTemp,actionTemp,indexTemp):
        #setup file address error
        if not(os.path.exists(campTemp)):
            self.errors+='方案模板:%s不存在;'%campTemp
        if not(os.path.exists(actionTemp)):
            self.errors+='动作模板:%s不存在;'%actionTemp
        if not(os.path.exists(indexTemp)):
            self.errors+='指标模板:%s不存在;'%indexTemp

        if self.errors=='':
            self.campObj=self.__loadYaml(campTemp)
            self.actionObj=self.__loadYaml(actionTemp)
            self.indexObj=self.__loadYaml(indexTemp)
        
        #setup file definition error
        #later

    #生成新的方案方案头
    def __genCampHead():
        if self.errors=='':
            newCamp=self.campObj

            #？此处需要用户输入单元 title,fid

            if title!='':
                newCamp['campHead']['id']=autoId


    #编辑活动方案
    #
    def 编辑方案(模块名):
        if 模块名=='' or 模块名=='方案标题':
            self.__genCampHead
        



fu=fuCamp(r'../actionTemplate.yaml',r'../actionTemplate.yaml',r'../indexTemp.yaml')
#print('erro:'+fu.errors)
#print('camp:\n%s\n\naction:\n%s\n\nindex:\n%s\n'%(fu.campObj,fu.actionObj,fu.indexObj))
#campob=fu.actionObj
#print(type(campob['actionTab']))
print autoId
